# %%
import xarray as xr
ds =  xr.open_mfdataset("/mnt/data/era530km/*.grib")

ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 24, isobaricInhPa: 5, latitude: 181, longitude: 781)
# Coordinates:
#     number         int64 ...
#   * time           (time) datetime64[ns] 2019-01-01 ... 2019-01-01T23:00:00
#     step           timedelta64[ns] ...
#   * isobaricInhPa  (isobaricInhPa) float64 850.0 700.0 500.0 300.0 200.0
#   * latitude       (latitude) float64 65.0 64.75 64.5 64.25 ... 20.5 20.25 20.0
#   * longitude      (longitude) float64 -140.0 -139.8 -139.5 ... 54.5 54.75 55.0
#     valid_time     (time) datetime64[ns] dask.array<chunksize=(24,), meta=np.ndarray>
# Data variables:
#     d              (time, isobaricInhPa, latitude, longitude) float32 dask.array<chunksize=(24, 5, 181, 781), meta=np.ndarray>
#     z              (time, isobaricInhPa, latitude, longitude) float32 dask.array<chunksize=(24, 5, 181, 781), meta=np.ndarray>
#     r              (time, isobaricInhPa, latitude, longitude) float32 dask.array<chunksize=(24, 5, 181, 781), meta=np.ndarray>
# ...

# %%
ds.isel(time=0,isobaricInhPa=0).z.plot.imshow()
