# %%
import datetime

import xarray as xr
import numpy as np



ds =  xr.open_zarr("gs://weatherbench2/datasets/era5/1959-2022-full_37-1h-0p25deg-chunk-1.zarr-v2").sel(time=np.s_[datetime.datetime(2019, 1, 1):])
ds
# ds
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 26304,
#                                                        latitude: 721,
#                                                        longitude: 1440,
#                                                        level: 37)
# Coordinates:
#   * latitude                                          (latitude) float32 90.0...
#   * level                                             (level) int64 1 2 ... 1000
#   * longitude                                         (longitude) float32 0.0...
#   * time                                              (time) datetime64[ns] 2...
# Data variables: (12/31)
#     10m_u_component_of_wind                           (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
#     10m_v_component_of_wind                           (time, latitude, longitude) float32 dask.array<chunksize=(1, 721, 1440), meta=np.ndarray>
# ...

# %%
GEOPOTENTIAL = "geopotential"
SPECIFIC_HUMIDITY = "specific_humidity"
TEMPERATURE = "temperature"
U_COMPONENT_OF_WIND = "u_component_of_wind"
V_COMPONENT_OF_WIND = "v_component_of_wind"
VERTICAL_VELOCITY = "vertical_velocity"

UPPER_AIR_VARIABLES = [
    GEOPOTENTIAL,
    SPECIFIC_HUMIDITY,
    TEMPERATURE,
    U_COMPONENT_OF_WIND,
    V_COMPONENT_OF_WIND,
    VERTICAL_VELOCITY,
]

ua = ds[UPPER_AIR_VARIABLES].sel(level=ds.level >= 200)
ua
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 26304, level: 23, latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude             (latitude) float32 90.0 89.75 89.5 ... -89.75 -90.0
#   * level                (level) int64 200 225 250 300 350 ... 925 950 975 1000
#   * longitude            (longitude) float32 0.0 0.25 0.5 ... 359.2 359.5 359.8
#   * time                 (time) datetime64[ns] 2019-01-01 ... 2021-12-31T23:0...
# Data variables:
#     geopotential         (time, level, latitude, longitude) float32 dask.array<chunksize=(1, 23, 721, 1440), meta=np.ndarray>
#     specific_humidity    (time, level, latitude, longitude) float32 dask.array<chunksize=(1, 23, 721, 1440), meta=np.ndarray>
#     temperature          (time, level, latitude, longitude) float32 dask.array<chunksize=(1, 23, 721, 1440), meta=np.ndarray>
#     u_component_of_wind  (time, level, latitude, longitude) float32 dask.array<chunksize=(1, 23, 721, 1440), meta=np.ndarray>
# ...

# %%
import toml

attrs = [
    (dvar,ua[dvar].attrs) for dvar in ua.data_vars
]

data_attrs = [
    attrs | {
        "standard_name": dvar, 
        "type_of_level": "isobaricInhPa",
        "coordinates": list(ds[dvar].coords.keys()),
        "description":""
    }
    for dvar, attrs in attrs
]

data_attrs
# Out:
# [{'long_name': 'Geopotential',
#   'short_name': 'z',
#   'standard_name': 'geopotential',
#   'units': 'm**2 s**-2',
#   'type_of_level': 'isobaricInhPa',
#   'coordinates': ['latitude', 'level', 'longitude', 'time'],
#   'description': ''},
#  {'long_name': 'Specific humidity',
#   'short_name': 'q',
#   'standard_name': 'specific_humidity',
#   'units': 'kg kg**-1',
#   'type_of_level': 'isobaricInhPa',
#   'coordinates': ['latitude', 'level', 'longitude', 'time'],
#   'description': ''},
#  {'long_name': 'Temperature',
#   'short_name': 't',
#   'standard_name': 'temperature',
#   'units': 'K',
#   'type_of_level': 'isobaricInhPa',
#   'coordinates': ['latitude', 'level', 'longitude', 'time'],
#   'description': ''},
#  {'long_name': 'U component of wind',
#   'short_name': 'u',
#   'standard_name': 'u_component_of_wind',
#   'units': 'm s**-1',
#   'type_of_level': 'isobaricInhPa',
#   'coordinates': ['latitude', 'level', 'longitude', 'time'],
#   'description': ''},
# ...

# %%
ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/leaver/mesoformer/wb2.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-22.04/home/leaver/mesoformer/wb2.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ds
#
# NameError: name 'ds' is not defined

# %%
ds[UPPER_AIR_VARIABLES].variables["geopotential"]
# Out:
# <xarray.Variable (time: 26304, level: 37, latitude: 721, longitude: 1440)>
# dask.array<getitem, shape=(26304, 37, 721, 1440), dtype=float32, chunksize=(1, 37, 721, 1440), chunktype=numpy.ndarray>
# Attributes:
#     long_name:      Geopotential
#     short_name:     z
#     standard_name:  geopotential
#     units:          m**2 s**-2
